# %%
# import statements and configuration
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# set theme
sns.set_theme(style="darkgrid")
figure_size=[10, 5]

# %%
# read data from csv to df
data = pd.read_csv('../../data/raw/world-happiness-report-2021.csv')
data.head()
# Out:
#   Country name Regional indicator  Ladder score  \
# 0      Finland     Western Europe         7.842
# 1      Denmark     Western Europe         7.620
# 2  Switzerland     Western Europe         7.571
# 3      Iceland     Western Europe         7.554
# 4  Netherlands     Western Europe         7.464
#
#    Standard error of ladder score  upperwhisker  lowerwhisker  \
# 0                           0.032         7.904         7.780
# 1                           0.035         7.687         7.552
# 2                           0.036         7.643         7.500
# 3                           0.059         7.670         7.438
# 4                           0.027         7.518         7.410
#
#    Logged GDP per capita  Social support  Healthy life expectancy  \
# 0                 10.775           0.954                     72.0
# 1                 10.933           0.954                     72.7
# 2                 11.117           0.942                     74.4
# ...

# %%
# check for missing value
data.isnull().sum() # no missing value :D
# Out:
# Country name                                  0
# Regional indicator                            0
# Ladder score                                  0
# Standard error of ladder score                0
# upperwhisker                                  0
# lowerwhisker                                  0
# Logged GDP per capita                         0
# Social support                                0
# Healthy life expectancy                       0
# Freedom to make life choices                  0
# Generosity                                    0
# Perceptions of corruption                     0
# Ladder score in Dystopia                      0
# Explained by: Log GDP per capita              0
# Explained by: Social support                  0
# Explained by: Healthy life expectancy         0
# Explained by: Freedom to make life choices    0
# Explained by: Generosity                      0
# Explained by: Perceptions of corruption       0
# Dystopia + residual                           0
# ...

# %%
# no unwanted columns
df = data

# %%
# plotting boxplot per region
fig, ax = plt.subplots(figsize=figure_size)

sns.boxplot(y='Regional indicator', x='Ladder score', data=df, palette='coolwarm', ax=ax)
sns.stripplot(y='Regional indicator', x='Ladder score', data=df, color='#114b5f', size=5, alpha=.7, ax=ax)

ax.set(title='Boxplot by Regional Indicator', ylabel='')
plt.show()

# %%
# plotting boxplot for each country per region

print(df['Regional indicator'].unique())
summary_per_region = []
for country in df['Regional indicator'].unique():
    summary_per_region.append([country, df.loc[df['Regional indicator'] == country]])
# print(summary_per_region)
    

fig, ax = plt.subplots(nrows=5, ncols=5, figsize=figure_size)
print(ax)

# for i in range(len(df['Regional indicator'].unique())):
graphs = []
for region in summary_per_region:
    _ax = sns.lineplot()
# Out:
# ['Western Europe' 'North America and ANZ' 'Middle East and North Africa'
#  'Latin America and Caribbean' 'Central and Eastern Europe' 'East Asia'
#  'Southeast Asia' 'Commonwealth of Independent States'
#  'Sub-Saharan Africa' 'South Asia']
# [[<AxesSubplot:> <AxesSubplot:> <AxesSubplot:> <AxesSubplot:>
#   <AxesSubplot:>]
#  [<AxesSubplot:> <AxesSubplot:> <AxesSubplot:> <AxesSubplot:>
#   <AxesSubplot:>]
#  [<AxesSubplot:> <AxesSubplot:> <AxesSubplot:> <AxesSubplot:>
#   <AxesSubplot:>]
#  [<AxesSubplot:> <AxesSubplot:> <AxesSubplot:> <AxesSubplot:>
#   <AxesSubplot:>]
#  [<AxesSubplot:> <AxesSubplot:> <AxesSubplot:> <AxesSubplot:>
#   <AxesSubplot:>]]

# %%
sns.scatterplot(data=df, y='Ladder score', x='')
